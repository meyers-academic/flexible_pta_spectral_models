# %%
# %load_ext autoreload
# %autoreload 2
import os, re

import discovery as ds
import PTMCMCSampler

from tqdm import tqdm

import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as pp

import jax
import jax.numpy as jnp
import glob
import matplotlib.pyplot as plt
from scipy.special import logsumexp
import numpyro
from numpyro import distributions as dist, infer
from numpyro.handlers import reparam
from numpyro.infer.reparam import LocScaleReparam
plt.style.use("/Users/patrickmeyers/Documents/Documents - Patrick’s MacBook Pro/Notes/cross_validation/meyers_latex.mplstyle")
import sys
sys.path.append("../modules")
import models as lncass_models
from lncass import PRIOR_DICT
# Out:
# Optional mpi4py package is not installed.  MPI support is not available.

# %%
# psrname = 'J1643-1224'
psrname = 'J1012+5307'
maindir = '/Users/patrickmeyers/Documents/Documents - Patrick’s MacBook Pro/repositories/pulsar_timing/pulsar_discovery/main_fork/discovery'
psrs = [ds.Pulsar.read_feather(psrfile) for psrfile in sorted(glob.glob(f'{maindir}/data/*-[JB]*.feather'))]
Tspan_pta = ds.getspan(psrs)
print(Tspan_pta / 365.25 / 86400)
names = [psr.name for psr in psrs]
idx = names.index(psrname)
psr = psrs[idx]
Tspan_psr = ds.getspan([psr])
n_rn_freqs = 30
# Out:
# 16.029777268872294

# %%
# for injection purposes
psrl = ds.PulsarLikelihood([psr.residuals,
                        ds.makenoise_measurement(psr, psr.noisedict),
                        ds.makegp_ecorr(psr, psr.noisedict),
                        ds.makegp_timing(psr, variance=1e-19),
                        ds.makegp_fourier(psr, ds.freespectrum, n_rn_freqs, T=Tspan_psr, name='red_noise')])

# %%
psrl.logL.params
# Out:
# ['J1012+5307_red_noise_log10_rho(30)']

# %%
freqs = np.arange(1, n_rn_freqs+1) / Tspan_psr
logf = np.log10(freqs)
injection = -8 + -1.5 * (logf - logf[0])
injection[5] += 1
injection[13] += 0.4
plt.plot(freqs, injection, '-o')
plt.show()

print(freqs.size)
# Out:
# 30

# %%
residuals = psrl.sample(jax.random.PRNGKey(34), {'J1012+5307_red_noise_log10_rho(30)': injection})
print(residuals[1])
# Out:
# [-1.59009420e-05  1.72063590e-06 -2.11959674e-06 ...  6.99636295e-07
#   3.71677502e-06 -2.48688465e-06]

# %%
psr.residuals = np.array(residuals[1])

# %%
plt.errorbar(psr.toas / 86400, psr.residuals, yerr=psr.toaerrs, fmt='.', alpha=0.05)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
model = lncass_models.create_rn_single_psr_model(psr, n_rn_freqs)

# %%
lncass_outliers_sampler = infer.MCMC(
    infer.NUTS(model, max_tree_depth=10),
    num_warmup=1000,
    num_samples=1000,
    num_chains=1,
    progress_bar=True,chain_method='vectorized'
)

# %%
with numpyro.validation_enabled():
    lncass_outliers_sampler.run(jax.random.PRNGKey(23), prior_dict={**PRIOR_DICT})
# Out:
# sample: 100%|██████████| 2000/2000 [03:20<00:00,  9.98it/s, 171 steps of size 1.37e-02. acc. prob=0.80]

# %%
samples = lncass_outliers_sampler.get_samples()

# %%
lncass_outliers_sampler.print_summary()
# Out:
#                          mean       std    median      5.0%     95.0%     n_eff     r_hat
#        beta_xi_o[0]      0.04      0.99      0.04     -1.70      1.51    595.73      1.00
#        beta_xi_o[1]      0.05      1.00      0.06     -1.53      1.77    745.43      1.00
#        beta_xi_o[2]      0.00      0.95     -0.02     -1.44      1.66    617.41      1.00
#        beta_xi_o[3]     -0.01      1.05     -0.04     -1.58      1.80    607.13      1.00
#        beta_xi_o[4]     -0.01      0.98     -0.01     -1.66      1.45    650.44      1.00
#        beta_xi_o[5]     -0.07      1.00     -0.08     -1.83      1.44    587.75      1.00
#        beta_xi_o[6]      0.07      1.01      0.10     -1.42      1.85    543.55      1.00
#        beta_xi_o[7]      0.03      0.96      0.06     -1.38      1.63    447.03      1.00
#        beta_xi_o[8]      0.05      1.00      0.04     -1.58      1.70    452.95      1.00
#        beta_xi_o[9]      0.01      0.97     -0.04     -1.45      1.66    621.57      1.00
#       beta_xi_o[10]     -0.01      1.02     -0.00     -1.62      1.76    402.85      1.00
#       beta_xi_o[11]     -0.04      1.02     -0.02     -1.76      1.61    467.12      1.00
#       beta_xi_o[12]      0.04      1.01      0.05     -1.48      1.81    502.93      1.00
#       beta_xi_o[13]      0.01      1.05      0.01     -1.75      1.65    463.10      1.00
#       beta_xi_o[14]      0.01      0.97      0.03     -1.55      1.67    521.58      1.00
#       beta_xi_o[15]     -0.01      1.06     -0.01     -1.80      1.71    816.75      1.00
#       beta_xi_o[16]      0.02      1.04     -0.03     -1.41      2.08    547.29      1.00
#       beta_xi_o[17]      0.07      1.01      0.05     -1.57      1.64    506.79      1.00
#       beta_xi_o[18]     -0.05      0.99     -0.04     -1.55      1.59    538.94      1.00
#       beta_xi_o[19]      0.05      1.01      0.06     -1.46      1.83    833.40      1.00
#       beta_xi_o[20]     -0.06      0.99     -0.06     -1.77      1.48    511.43      1.00
#       beta_xi_o[21]      0.03      0.98      0.06     -1.68      1.49    490.95      1.00
#       beta_xi_o[22]     -0.06      1.02      0.00     -1.65      1.60    487.98      1.00
#       beta_xi_o[23]     -0.01      1.01     -0.01     -1.65      1.58    505.83      1.00
#       beta_xi_o[24]     -0.02      0.96     -0.02     -1.66      1.51    508.95      1.00
#       beta_xi_o[25]      0.00      1.00     -0.03     -1.57      1.72    614.60      1.00
#       beta_xi_o[26]      0.01      1.00      0.02     -1.59      1.63    474.85      1.00
#       beta_xi_o[27]     -0.03      1.06     -0.04     -1.65      1.83    716.69      1.00
#       beta_xi_rn[0]      0.02      0.98      0.03     -1.43      1.80    638.31      1.00
#       beta_xi_rn[1]      0.01      0.95      0.03     -1.59      1.54    779.36      1.00
#       beta_xi_rn[2]     -0.04      1.00     -0.04     -1.68      1.61    673.71      1.00
#       beta_xi_rn[3]      0.03      1.01      0.02     -1.78      1.51    675.94      1.00
#       beta_xi_rn[4]     -0.02      0.96     -0.01     -1.50      1.56    483.85      1.00
#       beta_xi_rn[5]     -0.11      0.93     -0.14     -1.61      1.51    484.97      1.00
#       beta_xi_rn[6]     -0.04      1.03     -0.04     -1.63      1.75    547.74      1.00
#       beta_xi_rn[7]     -0.08      1.00     -0.04     -1.62      1.68    395.24      1.00
#       beta_xi_rn[8]     -0.08      1.01     -0.08     -1.62      1.61    589.96      1.00
#       beta_xi_rn[9]     -0.16      1.00     -0.17     -1.65      1.64    720.97      1.00
#      beta_xi_rn[10]     -0.06      0.96     -0.01     -1.62      1.53    418.67      1.00
#      beta_xi_rn[11]     -0.12      0.99     -0.11     -1.83      1.40    603.02      1.00
#      beta_xi_rn[12]     -0.12      1.00     -0.08     -1.91      1.42    532.69      1.00
#      beta_xi_rn[13]     -0.07      0.98     -0.04     -1.66      1.45    782.13      1.00
#      beta_xi_rn[14]     -0.09      1.01     -0.13     -1.68      1.67    613.70      1.00
#      beta_xi_rn[15]     -0.08      1.03     -0.10     -1.66      1.63    600.45      1.00
#      beta_xi_rn[16]     -0.12      0.92     -0.09     -1.44      1.40    619.18      1.00
#      beta_xi_rn[17]     -0.05      1.01     -0.07     -1.61      1.57    523.95      1.00
#      beta_xi_rn[18]     -0.10      0.94     -0.10     -1.55      1.45    899.61      1.00
#      beta_xi_rn[19]     -0.14      1.01     -0.13     -1.75      1.57    534.40      1.00
#      beta_xi_rn[20]     -0.08      1.02     -0.06     -1.87      1.43    611.31      1.00
#      beta_xi_rn[21]     -0.20      1.03     -0.16     -1.86      1.43    522.71      1.00
#      beta_xi_rn[22]     -0.09      0.97     -0.12     -1.81      1.50    751.79      1.00
#      beta_xi_rn[23]     -0.10      0.99     -0.11     -1.73      1.51    495.32      1.00
#      beta_xi_rn[24]     -0.09      1.04     -0.07     -1.68      1.78    940.76      1.00
#      beta_xi_rn[25]     -0.16      1.00     -0.12     -2.05      1.19    487.68      1.00
#      beta_xi_rn[26]     -0.09      1.00     -0.07     -1.66      1.57    403.04      1.00
#      beta_xi_rn[27]     -0.05      0.98     -0.06     -1.71      1.55    594.12      1.00
#   lambda_tilde_o[0]      0.11      8.54     -0.63    -12.10     13.15     46.22      1.00
#   lambda_tilde_o[1]      0.39      8.48      0.03    -12.79     13.29     58.84      1.00
#   lambda_tilde_o[2]      0.11      8.26     -0.35    -12.16     13.50     48.02      1.00
#   lambda_tilde_o[3]      0.31      8.20      0.14    -11.54     14.02     56.44      1.00
#   lambda_tilde_o[4]     -0.37      8.81     -0.67    -13.41     13.64     63.04      1.00
#   lambda_tilde_o[5]      0.27      8.43     -0.28    -11.64     15.62     58.13      1.01
#   lambda_tilde_o[6]      0.22      9.45     -0.20    -14.03     15.80     54.30      1.00
#   lambda_tilde_o[7]      0.37      8.69      0.19    -12.79     13.71     62.93      1.00
#   lambda_tilde_o[8]      0.01      8.74     -0.22    -12.70     14.12     46.66      1.01
#   lambda_tilde_o[9]      0.13      8.86     -0.28    -13.02     15.93     37.95      1.01
#  lambda_tilde_o[10]      0.32      8.93     -0.09    -12.91     15.51     49.01      1.00
#  lambda_tilde_o[11]     -0.03      8.60     -0.75    -11.17     15.66     54.05      1.00
#  lambda_tilde_o[12]      0.45      8.34      0.43    -11.77     14.17     49.36      1.01
#  lambda_tilde_o[13]      0.10      8.87     -0.48    -13.96     14.81     49.88      1.00
#  lambda_tilde_o[14]      0.36      8.87      0.37    -12.10     15.15     56.57      1.00
#  lambda_tilde_o[15]      0.13      8.74     -0.03    -13.26     14.34     53.11      1.00
#  lambda_tilde_o[16]      0.32      9.29     -0.25    -13.81     14.90     46.45      1.00
#  lambda_tilde_o[17]      0.49      8.66      0.48    -11.99     14.59     36.65      1.00
#  lambda_tilde_o[18]      0.04      9.25     -0.14    -14.21     14.10     39.12      1.01
#  lambda_tilde_o[19]      0.54      8.90     -0.42    -12.25     14.67     36.09      1.01
#  lambda_tilde_o[20]      0.20      8.86     -0.13    -12.77     15.21     61.16      1.00
#  lambda_tilde_o[21]      0.65      8.65     -0.04    -12.31     14.35     40.67      1.01
#  lambda_tilde_o[22]      0.37      9.13     -0.05    -13.25     15.05     44.52      1.00
#  lambda_tilde_o[23]      0.14      8.86     -0.36    -13.07     14.75     49.13      1.00
#  lambda_tilde_o[24]      0.59      8.82      0.16    -11.69     16.04     55.77      1.00
#  lambda_tilde_o[25]      0.29      8.46      0.47    -11.88     14.57     57.29      1.00
#  lambda_tilde_o[26]     -0.57      8.72     -1.09    -13.43     12.93     40.50      1.00
#  lambda_tilde_o[27]      0.60      8.62     -0.07    -12.58     13.43     51.64      1.00
#  lambda_tilde_rn[0]     -1.25      7.97     -2.88    -11.40     12.70     42.75      1.01
#  lambda_tilde_rn[1]     -1.00      7.73     -2.20    -11.34     12.16     37.77      1.00
#  lambda_tilde_rn[2]     -0.80      8.46     -2.09    -13.78     12.28     31.00      1.00
#  lambda_tilde_rn[3]     -1.24      8.32     -2.60    -12.75     12.55     37.59      1.01
#  lambda_tilde_rn[4]     -0.94      8.36     -2.56    -12.06     13.81     36.53      1.01
#  lambda_tilde_rn[5]     -0.74      7.99     -2.14    -11.96     12.28     35.60      1.00
#  lambda_tilde_rn[6]     -1.34      8.15     -2.51    -11.60     14.64     44.14      1.00
#  lambda_tilde_rn[7]     -1.08      8.63     -2.75    -14.72     13.16     35.00      1.01
#  lambda_tilde_rn[8]     -0.90      8.49     -2.15    -12.80     14.24     28.49      1.00
#  lambda_tilde_rn[9]     -0.83      8.57     -2.44    -12.57     13.77     49.91      1.00
# lambda_tilde_rn[10]     -0.68      8.07     -2.25    -10.99     12.73     29.06      1.01
# lambda_tilde_rn[11]     -1.22      8.04     -2.29    -13.08     11.13     35.27      1.00
# lambda_tilde_rn[12]     -0.55      8.37     -2.12    -12.42     11.69     31.41      1.01
# lambda_tilde_rn[13]     -0.69      7.88     -1.84    -12.74     11.25     31.35      1.01
# lambda_tilde_rn[14]     -1.05      8.00     -2.32    -12.03     11.93     34.38      1.00
# lambda_tilde_rn[15]     -0.92      7.79     -2.45    -10.26     13.07     28.42      1.01
# lambda_tilde_rn[16]     -1.05      8.19     -2.59    -13.10     11.96     36.25      1.00
# lambda_tilde_rn[17]     -0.96      8.57     -2.23    -11.65     14.50     30.53      1.01
# lambda_tilde_rn[18]     -0.79      8.09     -2.10    -11.52     12.43     26.64      1.01
# lambda_tilde_rn[19]     -0.86      8.04     -2.30    -11.13     12.86     29.02      1.01
# lambda_tilde_rn[20]     -1.00      8.23     -2.49    -11.89     13.50     42.71      1.00
# lambda_tilde_rn[21]     -0.64      8.34     -2.19    -11.30     13.13     36.91      1.01
# lambda_tilde_rn[22]     -1.19      8.23     -2.81    -12.48     12.24     38.71      1.00
# lambda_tilde_rn[23]     -0.64      7.96     -2.39    -11.89     12.25     29.47      1.01
# lambda_tilde_rn[24]     -0.96      8.24     -2.27    -11.41     12.50     37.82      1.00
# lambda_tilde_rn[25]     -1.08      8.07     -2.13    -12.09     12.44     42.95      1.00
# lambda_tilde_rn[26]     -0.90      8.10     -2.32    -12.25     12.66     31.69      1.01
# lambda_tilde_rn[27]     -0.90      8.47     -2.66    -12.61     12.84     36.36      1.00
#        log_10_rho_0    -11.20      2.45    -11.39    -14.97     -7.47    412.03      1.00
#     log_10_rho_last    -11.32      2.27    -11.36    -14.94     -8.10    526.89      1.00
#         mu_lambda_o      0.26      5.81      0.75     -9.89      8.38     23.87      1.01
#        mu_lambda_rn     -0.94      6.04     -1.99     -9.43      8.67     17.78      1.01
#      sigma_lambda_o      5.83      2.71      6.08      1.76      9.97     17.64      1.00
#     sigma_lambda_rn      4.45      3.23      4.42      0.22      9.16      9.84      1.00
#               tau_o      1.38      2.93      0.75      0.00      2.96    609.80      1.00
#              tau_rn      5.03     32.38      0.79      0.00      6.02    262.94      1.00
#
# Number of divergences: 46

# %%
plt.figure(figsize=(10, 5))
plt.violinplot(samples['log10_rho'].squeeze(), showextrema=False)
plt.plot(np.arange(1, n_rn_freqs+1), injection, '-o', lw=1)
plt.ylim(-15, -4)
plt.show()

# %%
plt.hist(samples['log10_rho'].squeeze()[:, 8])
plt.show()

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 5))
for ii in range(30):
    idx = np.random.randint(0, samples['log10_rho'].shape[0])
    if np.any(samples['log10_rho'].squeeze()[idx, :] ==-15):
        print(idx)
    ax[0].plot(logf, samples['log10_rho'].squeeze()[idx, :], '-o', c='k', alpha=0.03)
    ax[1].plot(logf[1:-1], samples['beta_rn'].squeeze()[idx, :], '-o', c='k', alpha=0.03)
ax[0].set_ylim(-16, -13)
# Out:
# 835
# 648
# 421
# 674
# 990
# 573
# 900
# 413
# 168
# 518
# 722
# 643
# 442
# 337
# 413
# 177
# 309
# 486
# 691
# 80
# 359
# 632
# 709
# (-16.0, -13.0)

# %%
idx_test = 80
plt.plot(samples['log10_rho'].squeeze()[idx_test, :], '-o')
plt.show()
plt.plot(samples['beta_rn'].squeeze()[idx_test, :], '-o')
plt.show()
plt.plot(samples['beta_o'].squeeze()[idx_test, :], '-o')
plt.show()

# %%
plt.violinplot(samples['beta_o'], showextrema=False)
plt.show()

# %%
plt.hist(np.log(samples['sigma_lambda_rn']))
plt.show()

# %%
plt.hist((samples['mu_lambda_rn']))
plt.show()

# %%
samples['lambdas_rn'].shape
# Out:
# (1000, 28)

# %%
from scipy.special import expit
def plot_lncass_priors(samples, tag='rn'):
    fig, axes = plt.subplots(2, 2, figsize=(10, 7))
    axes = axes.ravel()
    # histogram sigma_lambda_rn
    axes[0].hist(samples[f'sigma_lambda_{tag}'], bins='auto', density=True, histtype='stepfilled', color='b', alpha=0.5)
    axes[0].set_title(f'$\\sigma_{{\\lambda_{{ {tag} }}}}$')
    # histogram mu_lambda_rn
    axes[1].hist(samples[f'mu_lambda_{tag}'], bins='auto', density=True, histtype='stepfilled', color='b', alpha=0.5)
    axes[1].set_title(f'$\\mu_{{\\lambda_{{ {tag} }}}}$')
    # get prior on b's
    lam_prior_vals = []
    b_prior_vals = []
    for ii in range(1000):
        idx = np.random.randint(0, samples[f'tau_{tag}'].shape[0])
        lam_prior = expit(np.random.randn(100, 28) * samples[f'sigma_lambda_{tag}'][idx] + samples[f'mu_lambda_{tag}'][idx])
        lam_prior_vals.extend(lam_prior.tolist())
        bvals = np.random.randn(100, 28) * lam_prior * samples[f'tau_{tag}'][idx]
        b_prior_vals.extend(bvals)
    lam_prior_vals = np.array(lam_prior_vals)

    b_prior_vals = np.array(b_prior_vals)
    axes[2].hist(lam_prior_vals.flatten(), bins=50, density=True, histtype='step', color='b', alpha=0.5)
    axes[2].set_title(f'$\\lambda_{{ {tag} }}$ Prior')
    axes[2].set_yscale("log")
    # axes[2].set_xscale("log")
    axes[3].hist(b_prior_vals.flatten(), bins=200, density=True, histtype='step', color='b', alpha=0.5)
    # axes[3].set_yscale("log")
    axes[3].set_ylim(0, 0.01)
    axes[3].set_title(f'$b_{{ {tag} }}$ Prior')
    plt.tight_layout()
    plt.show()

# %%
plot_lncass_priors(samples)
plot_lncass_priors(samples, tag='o')

# %%
import matplotlib.gridspec as gridspec

def plot_lncass_posteriors(samples, tag='rn'):
    fig, axes = plt.subplots(2, 1, figsize=(10, 7))
    axes = axes.ravel()
    axes[0].violinplot(samples[f'beta_{tag}'], showextrema=False)
    axes[0].set_title(f'$\\beta_{{ {tag} }}$')
    
    axes[1].violinplot(samples[f'lambdas_{tag}'], showextrema=False)
    axes[1].set_title(f'$\\lambda_{{ {tag} }}$')
    
    plt.tight_layout()
    plt.show()

plot_lncass_posteriors(samples)
plot_lncass_posteriors(samples, tag='o')

# %%
plt.violinplot(samples['log10_rho'].squeeze(), showextrema=False)
plt.ylim(-8, -5)
plt.show()

# %%
plt.scatter(samples['mu_lambda_o'], samples['sigma_lambda_o'], s=1, alpha=0.3)
ax =    plt.gca()
ax.axhline(1, c='k')

# %%
pl_model = lncass_models.create_single_psr_powerlaw_model(psr, n_rn_freqs)
pl_sampler = infer.MCMC(
    infer.NUTS(pl_model, max_tree_depth=10),
    num_warmup=10000,
    num_samples=10000,
    num_chains=1,
    progress_bar=True,chain_method='vectorized'
)

# %%
with numpyro.validation_enabled():
    pl_sampler.run(jax.random.PRNGKey(13))
# Out:
# sample: 100%|██████████| 20000/20000 [00:38<00:00, 519.51it/s, 7 steps of size 4.61e-01. acc. prob=0.74]

# %%
fspec_model = lncass_models.create_single_psr_freespec_model(psr, n_rn_freqs)
fspec_sampler = infer.MCMC(
    infer.NUTS(fspec_model, max_tree_depth=10),
    num_warmup=1000,
    num_samples=1000,
    num_chains=1,
    progress_bar=True,chain_method='vectorized'
)

# %%
with numpyro.validation_enabled():
    fspec_sampler.run(jax.random.PRNGKey(13))
# Out:
# sample: 100%|██████████| 2000/2000 [00:19<00:00, 100.46it/s, 31 steps of size 1.06e-01. acc. prob=0.89]

# %%
fspec_samples = fspec_sampler.get_samples()
pl_samples = pl_sampler.get_samples()

# %%
pl_samples.keys()
# Out:
# dict_keys(['log10_A', 'log10_gamma'])

# %%
freqs = np.arange(1, 31) / ds.getspan([psr])
fyr = 1 / 365.25 / 86400
pl_rhos = np.array([np.log10(10**(2*pl_samples['log10_A'][idx]) / (12 * np.pi**2) * (freqs / fyr)**(-pl_samples['log10_gamma'][idx]) * fyr**-3 / ds.getspan([psr])) / 2  for idx in range(1000)])

# %%
pl_rhos.shape
# Out:
# (1000, 30)

# %%
plt.figure(figsize=(10, 4))
plt.violinplot(fspec_samples['log10_rho'].squeeze(), showextrema=False, side="low", widths=0.9)
plt.violinplot(samples['log10_rho'].squeeze(), showextrema=False, side="high", widths=0.9)
freqs = np.arange(1, 31) / ds.getspan([psr])
plt.plot(np.arange(1, n_rn_freqs+1), injection, '-o', lw=1)

plt.ylim(-8, -4)

for ii in range(1000):
    idx = np.random.randint(0, pl_samples['log10_A'].shape[0])
    tr = np.log10(10**(2*pl_samples['log10_A'][idx]) / (12 * np.pi**2) * (freqs / fyr)**(-pl_samples['log10_gamma'][idx]) * fyr**-3 / ds.getspan([psr])) / 2
    plt.plot(np.arange(1, 31), tr, c='k', alpha=0.002, zorder=-1000)

# %% [markdown]
# # Direct deviation from power law

# %%
spline_model = lncass_models.create_rn_single_psr_spline_model(psr, n_rn_freqs, 60)
spline_sampler = infer.MCMC(
    infer.NUTS(spline_model, max_tree_depth=10),
    num_warmup=3000,
    num_samples=3000,
    num_chains=1,
    progress_bar=True,chain_method='vectorized'
)

# %%
with numpyro.validation_enabled():
    spline_sampler.run(jax.random.PRNGKey(23), prior_dict={**PRIOR_DICT})
# Out:
# sample: 100%|██████████| 6000/6000 [03:57<00:00, 25.30it/s, 255 steps of size 1.88e-02. acc. prob=0.88]

# %%
spline_samples = spline_sampler.get_samples()

# %%
plt.figure(figsize=(10, 8))
plt.violinplot(spline_samples['log10_rho'].squeeze(), showextrema=False, side="low", widths=0.9)
plt.violinplot(samples['log10_rho'].squeeze(), showextrema=False, side="high", widths=0.9)
plt.violinplot(pl_rhos, showextrema=False, side="high", widths=0.9)
plt.ylim(-15, -5)
plt.plot(np.arange(1, n_rn_freqs+1),  injection, '-o')
# for ii in range(1000):
#     idx = np.random.randint(0, pl_samples['log10_A'].shape[0])
#     tr = np.log10(10**(2*pl_samples['log10_A'][idx]) / (12 * np.pi**2) * (freqs / fyr)**(-pl_samples['log10_gamma'][idx]) * fyr**-3 / ds.getspan([psr])) / 2
#     plt.plot(np.arange(1, 31), tr, c='k', alpha=0.002, zorder=-1000)
plt.show()

# %%
plt.violinplot(spline_samples['beta_rn'].squeeze(), showextrema=False, widths=0.9)
plt.ylim(-2, 2)
plt.show()

# %%
plt.violinplot(spline_samples['lambdas_rn'].squeeze(), showextrema=False, widths=0.9)
plt.show()
